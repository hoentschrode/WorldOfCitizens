# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(6, 7))
gspec = fig.add_gridspec(ncols=3, nrows=2, height_ratios=[5, 5], wspace=0.4)

# Create the plots
map_ax = fig.add_subplot(gspec[0, 0:2])
small1 = fig.add_subplot(gspec[0, 2])
chart_ax = fig.add_subplot(gspec[1, 0])
chart2_ax = fig.add_subplot(gspec[1,1])

map_ax.set_xticklabels([])
map_ax.set_xticks([])
map_ax.set_yticklabels([])
map_ax.set_yticks([])
plt.show()

# %%
fig = plt.figure(figsize=(6, 7))
gspec = fig.add_gridspec(ncols=2, nrows=5, wspace=0.4, hspace=0.5)

# Create the plots
map_ax = fig.add_subplot(gspec[0:4, 0])

right1_ax = fig.add_subplot(gspec[0, 1])
right2_ax = fig.add_subplot(gspec[1, 1])
right3_ax = fig.add_subplot(gspec[2, 1])
right4_ax = fig.add_subplot(gspec[3, 1])

sir_ax = fig.add_subplot(gspec[4, :])

map_ax.set_xticklabels([])
map_ax.set_xticks([])
map_ax.set_yticklabels([])
map_ax.set_yticks([])
plt.show()
